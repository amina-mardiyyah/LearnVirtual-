# %% [markdown]
# # INTRODUCTION TO MATPLOTLIB
# - Is Python's main Visualization Library
# - Used for 2D Plots
# - Has multifunctionalities
# - Has two main styles ( **MATLAB** Style and **Object Oriented Style**)

# %% [markdown]
# # STEPS
# - Install the Library
# - Import the Library along with other wrappers/necessary libaries (Numpy,Pandas)
# - Check for version
# - Create/Import the data

# %% [markdown]
# ## Import the Library/Libraries
# ### How to Import the Matplotlib Library
#
# - **import matplotlib as mpl**
# - **from matplotlib import ***
# - **from matplotlib import pyplot as plt**
# - **import matplotlib.pyplot as plt**
#
# ##### N.B "Pyplot is a submodule of matplotlib".
#
# ### Other Libraries/Wrappers needed
# - Numpy
# - Pandas

# %%
#We'll be sticking with the 4th method, because it's the general convention and most popularly used
import matplotlib
import matplotlib.pyplot as plt #Loading Matplotlib plotting tools

#we'll also import numpy and pandas for data manipulation

import pandas as pd

import numpy as np
# %matplotlib inline

# %%
#We'll check for the versions of the libraries installed
print(f'Matplotlib:', matplotlib.__version__)
print(f'Numpy:', np.__version__)
print(f'Pandas:', pd.__version__)
# Out:
# Matplotlib: 3.1.3
# Numpy: 1.18.1
# Pandas: 1.0.2

# %% [markdown]
# ## Different types of plots you can create with Matplotlib library
# - Histograms
# - Barcharts
# - PieCharts
# - Line Graphs
# - Scatter Plots et cetera
#
# *You can Also make subplots in one line and include legends, and titles.*
#
# ### DIFFERENT FUNCTIONS USED FOR CREATING PLOTS IN MATPLOTLIB
#
# - plot() - for line plots
# - scatter() - for scatter plots
# - pie() - for piechart
# - hist() - for Histogram
# - bar() - for BarCharts
# - barh() - for horizontal barcharts

# %% [markdown]
# ## 1. MAKING BASIC PLOTS USING THE MATLAB STYLE IN MATPLOTLIB

# %%
#making a simple plot with matplotlib using a simple data
#A simple line graph
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 9, 10]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Adding Labels to the Plot

# %%
#addiing more arguments to the plot
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 9, 10]
plt.plot(x,y)
plt.title('A plot of X vs Y')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# ### Changing font size

# %%
#addiing more arguments to the plot
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 9, 10]
plt.plot(x,y)
plt.title('A plot of X vs Y', fontsize=18)
plt.xlabel('X-axis', fontsize=16)
plt.ylabel('Y-axis', fontsize=16)
plt.show()

# %% [markdown]
# ### Adjusting tick size

# %%
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 9, 10]
plt.plot(x,y)
plt.title('A plot of X vs Y', fontsize=18)
plt.xlabel('X-axis', fontsize=16)
plt.ylabel('Y-axis', fontsize=16)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %% [markdown]
# ### Adding markers

# %%
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 9, 10]
plt.plot(x,y, marker = '.', markersize = 10)
plt.title('A plot of X vs Y', fontsize=18)
plt.xlabel('X-axis', fontsize=16)
plt.ylabel('Y-axis', fontsize=16)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %% [markdown]
# ## Changing Marker Type and Colors
#
# ### Marker Type
# Here are a couple common marker types.
#
# string | description
# --- | ---
# '.' | point marker
# ',' | pixel marker
# 'o' | circle marker
# 'v' | triangle_down marker
# '^' | triangle_up marker
# '<' | triangle_left marker
# '>' | triangle_right marker
# 's'	| square marker
# '\*' | star marker
# '+' | plus marker
# 'x' | x marker
# 's'	| square marker

# %% [markdown]
# ## Let's make more Plots to see other functionalities

# %%
#Making a multiple plots and adding a legend
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 9, 10]
z = [1, 3, 5, 7, 9]
plt.plot(x,y, marker='v')
plt.plot(x,z, marker='*')
plt.title('A plot of X Vs Y and X Vs Z')
plt.xlabel('X-axis')
plt.ylabel('Y-axis and Z-axis')
plt.legend(['X vs z', 'X vs y'])
plt.show()

# %% [markdown]
# ## Moving the Position of the Legend

# %%
plt.plot(x,y, marker='v')
plt.plot(x,z, marker='*')
plt.title('A plot of X Vs Y and X Vs Z')
plt.xlabel('X-axis')
plt.ylabel('Y-axis and Z-axis')
plt.legend(['X vs z', 'X vs y'],loc=(1.02,0), borderaxespad=0, fontsize = 20)
plt.show()

# %%
plt.plot(x,y, marker='v')
plt.plot(x,z, marker='*')
plt.title('A plot of X Vs Y and X Vs Z')
plt.xlabel('X-axis')
plt.ylabel('Y-axis and Z-axis')
plt.legend(['X vs z', 'X vs y'],loc=('best'), borderaxespad=0, fontsize = 20)
plt.show()

# %% [markdown]
# ### Some other Locations of the Legends you can use
# - best
# - upper right
# - upper left
# - lower left
# - lower right
# - right
# - center left
# - center right
# - lower center
# - upper center
# - center
# - Tuple location (0,1), (1,0), (1.02,0), (0,1.02)

# %% [markdown]
# ## Changing Color
# The `c` parameter accepts strings.
#
# string | color
# --- | ---
# 'b' | blue
# 'blue' | blue
# 'g' | green
# 'green' | green
# 'r' | red
# 'red' | red
# 'c' | cyan
# 'cyan' | cyan
# 'm' | magenta
# 'magenta' | magenta
# 'y' | yellow
# 'yellow' | yellow
# 'k' | black
# 'black' | black
# 'w' | white
# 'white' | white
#
# The parameter also accepts hex strings. For instance, green is '#008000'. Additionally you can use rgb tuples.

# %%
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 9, 10]
z = [1, 3, 5, 7, 9]
plt.plot(x,y, c='m')
plt.plot(x,z, c='c')
plt.title('A plot of X Vs Y and X Vs Z')
plt.xlabel('X-axis')
plt.ylabel('Y-axis and Z-axis')
plt.legend(['X vs z', 'X vs y'])
plt.show()

# %% [markdown]
# ### Task: Try using the Hex Strings Color Coding
# - `#e5ae38` - for Yellow
# - `#444444` - for Black
# - `#008fd5` - for a lighter shade of blue
#
# read more about the color coding here: https://matplotlib.org/2.1.1/api/_as_gen/matplotlib.pyplot.plot.html

# %% [markdown]
# ### ALSO TRY : RGB TUPLES
# - ` (0, 0, 0) is black`
# - `(0, 0, 1) is blue`
# - `(0, 1, 0) is green`
# - `(1, 0, 0) is red`
# - `(1, 1, 0) is Yellow`

# %%
# Using rgb tuples
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 9, 10]
z = [1, 3, 5, 7, 9]
plt.plot(x,y, c=(0,0,1))
plt.plot(x,z, c=(0,1,0))
plt.title('A plot of X Vs Y and X Vs Z')
plt.xlabel('X-axis')
plt.ylabel('Y-axis and Z-axis')
plt.legend(['X vs z', 'X vs y'])
plt.show()

# %% [markdown]
# ## SCATTER PLOTS

# %%
## SCATTER PLOTS using matlab style plt.scatter()
x = [10,100,14,15,20,20,19]
y= [25,6,8,9,0,77,65]
plt.scatter(x,y)
plt.show()

# %%
#Another example
from numpy.random import rand
x, y = rand(2, 400)
plt.scatter(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('A simple Scatter Plot')
plt.show()

# %%
#Including scale
x, y, scale = rand(3, 200)
scale = 500 * scale ** 5
plt.scatter(x, y, s=scale)

# %% [markdown]
# ## Histograms

# %%
x = np.random.randn(1000)
plt.hist(x)
# Out:
# (array([ 14.,  28.,  85., 168., 269., 227., 135.,  55.,  18.,   1.]),
#  array([-2.93923938, -2.3123815 , -1.68552362, -1.05866574, -0.43180786,
#          0.19505002,  0.8219079 ,  1.44876578,  2.07562366,  2.70248154,
#          3.32933942]),
#  <a list of 10 Patch objects>)

# %%
#Let's add bins and color
plt.hist(x, bins=20, color='m')
# Out:
# (array([  5.,   9.,   9.,  19.,  36.,  49.,  64., 104., 125., 144., 122.,
#         105.,  82.,  53.,  42.,  13.,  12.,   6.,   0.,   1.]),
#  array([-2.93923938, -2.62581044, -2.3123815 , -1.99895256, -1.68552362,
#         -1.37209468, -1.05866574, -0.7452368 , -0.43180786, -0.11837892,
#          0.19505002,  0.50847896,  0.8219079 ,  1.13533684,  1.44876578,
#          1.76219472,  2.07562366,  2.3890526 ,  2.70248154,  3.01591048,
#          3.32933942]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ### Adding Grids

# %%
plt.hist(x, bins=20, color='c')
plt.grid(True)

# %% [markdown]
# ## Tasks:
# ## 'Create a variable, using any method you wish . Create an Histogram from it using the  `.hist()` function, play around with the color and fontsize, add labels'

# %% [markdown]
# ## Adding Styles/Themes
# ### `You can check for the different styles available in the Library and choose your preference`

# %%
#Checking for the available styles in Matplotlib
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
#How to use Styles
plt.style.use('bmh')
plt.hist(x, bins=20, color='c')
plt.grid(True)
plt.xlabel('X-Axis')
plt.ylabel('Y-axis')
plt.title('A simple Histogram')
# Out:
# Text(0.5, 1.0, 'A simple Histogram')

# %%
plt.style.use('classic')
plt.hist(x, bins=20, color='c')
plt.grid(True)
plt.xlabel('X-Axis')
plt.ylabel('Y-axis')
plt.title('A simple Histogram')
# Out:
# Text(0.5, 1.0, 'A simple Histogram')

# %%
plt.style.use('ggplot')
plt.hist(x, bins=20, color='c')
plt.xlabel('X-Axis')
plt.ylabel('Y-axis')
plt.title('A simple Histogram')
# Out:
# Text(0.5, 1.0, 'A simple Histogram')

# %%
plt.style.use('fivethirtyeight')
plt.hist(x, bins=20, color='r')
plt.xlabel('X-Axis')
plt.ylabel('Y-axis')
plt.title('A simple Histogram')
# Out:
# Text(0.5, 1.0, 'A simple Histogram')

# %%
plt.style.use('seaborn')
plt.hist(x, bins=20, color='r')
plt.xlabel('X-Axis')
plt.ylabel('Y-axis')
plt.title('A simple Histogram')
# Out:
# Text(0.5, 1.0, 'A simple Histogram')

# %% [markdown]
# ## Task: Try out any style of your choice on your previous Histogram

# %%
### You can also add an alpha parameter to your plots to determine the thickness of the color
plt.style.use('fast')
plt.grid(True)
plt.hist(x, bins=20, color='deeppink', alpha=0.2)
plt.xlabel('X-Axis')
plt.ylabel('Y-axis')
plt.title('A simple Histogram')
#the higher the alpha the darker the color
#the lower the alpha the lighter the color
# Out:
# Text(0.5, 1.0, 'A simple Histogram')

# %% [markdown]
# ### *Look up other plot arguments on the documentation*
# - `Color Palette/Coding - https://matplotlib.org/2.0.0/examples/color/named_colors.html`
# - `Plot Argument - https://matplotlib.org/2.1.1/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py`

# %% [markdown]
# # Bar Charts
# - The bar() function in Matplotlib takes two arguments **(x,y)**
# - While X = a category
# - Y = A numeric value

# %%
data = {'Tutors': ['Aminah', 'Adeola', 'Fatimah', 'Stephen', 'Femi', 'Isreal', 'Olayinka'],
        'Participants': ['joseph', 'Benjamin', 'Emmanuel', 'Kafee', 'Onyinye', 'Dominique', 'Andiwa'],
        'tutors_gender': ['Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male'],
        'participant_gender': ['Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female'], 
        'Age':[25,29,24,34,32,27,30]}
Data = pd.DataFrame(data)
Data.head()
# Out:
#     Tutors Participants tutors_gender participant_gender  Age
# 0   Aminah       joseph        Female               Male   25
# 1   Adeola     Benjamin        Female               Male   29
# 2  Fatimah     Emmanuel        Female               Male   24
# 3  Stephen        Kafee          Male             Female   34
# 4     Femi      Onyinye          Male             Female   32

# %%
plt.style.use('classic')
x = Data.Tutors
y = Data.Age

plt.bar(x,y, color='chocolate')
plt.xlabel('Tutors-Gender')
plt.ylabel('Age-range')
# Out:
# Text(0, 0.5, 'Age-range')

# %%
#Creating an Horizontal barchart
plt.style.use('classic')
x = Data.Tutors
y = Data.Age

plt.barh(x,y, color='tomato')
plt.xlabel('Tutors-Gender')
plt.ylabel('Age-range')
# Out:
# Text(0, 0.5, 'Age-range')

# %%
#Adding arguments
plt.style.use('seaborn-muted')
x = Data.Tutors
y = Data.Age

plt.barh(x,y, color='indianred',align='center')
plt.xlabel('Tutors-Gender')
plt.ylabel('Age-range')

# %% [markdown]
# ## Saving Your Plots to Your Local Computer

# %%
plt.style.use('seaborn-pastel')
x = Data.Tutors
y = Data.Age

plt.barh(x,y, color='indianred',align='center')
plt.xlabel('Tutors-Gender')
plt.ylabel('Age-range')
plt.grid(True)
plt.savefig('A simple Hist', dpi=300)

# %% [markdown]
# ### You could also specify a path
# ### Add a resolution
# ### Add a transparency option

# %% [markdown]
# # Object-Oriented Style Plotting
#
# #### *The difference is in the syntax*

# %%
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 9, 10]
fig = plt.figure()
ax = plt.axes()
ax.plot(x,y)

# %%
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 9, 10]
z = [1, 3, 5, 7, 9]
fig = plt.figure()
ax = plt.axes()
ax.plot(x,y, c='m')
ax.plot(x,z, c='c')
ax.set(title='A plot of X Vs Y and X Vs Z', xlabel='X-axis',ylabel='Y-axis')
ax.set_legend('')
ax.set_title()
ax.set_xlabel()
#plt.legend(['X vs z', 'X vs y'], loc=('best'))

# %% [markdown]
# ## Assignment
# - Replicate the other plots we made using Matlab style in Object oriented style
# - Create a Dataframe with numeric and categorical datatype columns # Do this after you learn how to work with `Pandas` on thursday.#
# - Create an Histograms with the Numerical columns
# - Create BarCharts from the Categorcial Columns
# - Create a data on a random population such that we have frequencies
# - Explore how to Create Piecharts
# - **DO not forget** to play around with the different styles , colors and other arguments in your plots.Explore your creativity
# - Create a Dataframe for Reported Covid-19 cases in Nigeria, numbers vs state, choose wisely the best plot to visualize it. -#this too - Thursday assignment
